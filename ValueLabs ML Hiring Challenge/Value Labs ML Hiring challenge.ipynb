# %% [markdown]
# # [1] Distractor generation for multiple choice questions:

# %% [markdown]
# ## [2] Importing important libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm

from collections import defaultdict
from collections import Counter 
from scipy.sparse import hstack
import operator

import re
import pickle

import warnings
warnings.filterwarnings("ignore")

import gc #Garbage collector.

# %% [markdown]
# <h4> Settings for Pandas, Seaborn </h4>

# %%
tqdm.pandas()
plt.style.use('ggplot')
#%config InlineBackend.figure_format = 'retina'
sns.set(rc={'figure.figsize':(10, 5)})

# %%
pd.options.display.max_columns=50
pd.options.display.max_rows=100

# %% [markdown]
# <h2> Problem Statement </h2>
# <h3> Generating Distractors for questions </h3>
#
# MCQs are a widely question format that is used for general assessment on domain knowledge of candidates. Most of the MCQs are created as paragraphs-based questions.
#
# A paragraph or code snippet forms the base of such questions. The questions are created based on three or four options from which one option is the correct answer. The othe remaining options are called the distractors which means that these options ar eneares to the correct answer but are not correct.
#
# You are provided with training dataset of questions, answers, and distractors to build and train an **NLP** model. The **test** dataset contains questions and answers. You are required to use your NLP model to create up to **three** distractors for each question-answer combination provided in the Test data.
#
# <h3> Data Description: </h3>
#
# - Train.csv 31499 * 3 (excluding headers)
# - Test.csv 13500 * 2 (excluding headers)
#
# |Column|Description|
# |------|-----------|
# |Question|Question of MCQs|
# |Answer|Correct answer of the corresponding question|
# |Distractor|Options that closely related to the correct answer but are not the correct answer|
#
# <h3> Submission format: </h3>
#
# - Your task is to create upto **three** distractors for each question-answer combination provided in the **Result.csv** file.
# - Each distractor must be placed between quotes (' ' or " ") and must be separeated by a comma(,).
# - This format can be observed in the traning dataset.
#
# **Note:** To avoid evaluation errors, it is recommended that you must update the values under the **'distractor'** column that is available in the provided **Results.csv** file compliant to the expected submission format.
#
# **Sample_submissions**
#
# |question|answer_text|Distractors|
# |--------|-----------|-----------|
# |Which city's landmarks include: The Pantheon,The Spanish Steps and Trevi Fountain?
# - The pantheon
# - The Spanish Steps
# - Trevi Fountain | Rome | 'Barcelona','Athens','Istanbul'
# |What is the color of Donald Duck's bowtie?|Red|'Blue','Yellow',"green'
# |What is a Web browser?|A software program that allows you to access sites on the World Wide Web| 'A kind of spider','A computer that stores WWW files','A person who likes to look at websites'
#
#
# <h3> Evaluation criteria </h3>
#
# For each question-answer combination, the distractors are converted to a **counter** vector of words and the **cosine similarity** is calculated between the predicted and the actual value:
# score = **100*mean([cosine_similarity(text_to_vector(actual_value),text_to_vector(predicted_value))])**
#
# ======================================================================================================================

# %% [markdown]
# <h2> Approach: </h2>
#
# Developing distractors has one of the most challenging and time-consuming tasks for a question-setter.
#
# <h4> Different ways for Generating distractor: </h4>
#
# 1. Can be generated from and after learning the context/concept from the passage(if provided) by training a Generative model. This can be achieved by generating texts from the passage that are close to answers but not exactly the same. But the grammar and POS of the generated text might be all messed up which is undesirable.
# 2. Text can be generated just by considering the left context of right-most word. This can be achieved by training a GPT2 model. But if we don't have long sequences of texts it is difficult to train a model that generates grammatically correct sentences.
# 3. If we have a collection of potential distractors or "candidate distractors" we can choose the most similar distractors to the Question-Answer pair. The idea is to produce semantically meaningful sentence embeddings for Question-Answer pairs and the Distractors.
#
# Here, I have choosen the 2nd approach since we need grammatically correct distractors. But if the passages were provided it is possible to generate distractors that are close to the context of the passage without compromising too much on their gramatical correctness. This can be achieved by leveraging from pre-trainded wide bidirectional encoder-decoder neural network architectures such as BERT.

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

print("Number of data points in Train:",train.shape[0])
print("Number of data points in Test:",test.shape[0])

print(train.info())
print(test.info())
# Out:
# Number of data points in Train: 31499
# Number of data points in Test: 13500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31499 entries, 0 to 31498
# Data columns (total 3 columns):
# question       31499 non-null object
# answer_text    31499 non-null object
# distractor     31499 non-null object
# dtypes: object(3)
# memory usage: 738.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13500 entries, 0 to 13499
# Data columns (total 5 columns):
# question       13500 non-null object
# answer_text    13500 non-null object
# distractor     13500 non-null object
# distractor2    13500 non-null object
# distractors    13500 non-null object
# dtypes: object(5)
# memory usage: 527.4+ KB
# None

# %% [markdown]
# ## [4] Exploratory Data Analysis:

# %%
#Checking for duplicates.
print(train.duplicated(keep = False).any())
print(test.duplicated(keep = False).any())
# Out:
# False
# False

# %%
train.tail(20)
# Out:
#                                                 question  \
# 31479  The trucking company 's lawyer insisted Farmer...
# 31480                    The participant of the research
# 31481  Which of the following models should you choos...
# 31482  Which of the following is WRONG according to t...
# 31483                       Daniel Goleman believes that
# 31484  According to the passage , what is the main di...
# 31485  According to Airbus , which of the following i...
# 31486  According to the passage , a dog will be most ...
# 31487                      Which one is the best title ?
# 31488         The destruction of Agadir is an example of
# 31489      Why is Venice still getting lower and lower ?
# 31490                 We can infer from the passage that
# 31491  Which of the following is TRUE about Western b...
# 31492                    The main idea of the passage is
# 31493               From the passage , we can learn that
# 31494                 John loved Tally so much , because
# 31495  You are a student of thirteen . If you want to...
# 31496                  Which of the following is right ?
# 31497  According to Galbraith , people feel disconten...
# 31498  The boy grew up with the smell of the herbs be...
#
#                                              answer_text  \
# 31479  because he believed the answer should be in hi...
# 31480       may work in a private office or in a cubicle
# 31481  Sony Ericsson 's W800i and Sumsung 's SPH - V5400
# 31482  There are no secrets in the book Duke of Zhou ...
# 31483  people not having high EQ may not be successfu...
# 31484  Ritual has a religious purpose and drama does ...
# 31485       Creating less pollution , having less weight
# 31486                                    familiar humans
# 31487                          How to be a good reader .
# 31488                       faulty building construction
# 31489  Because the rising temperature has made the ic...
# 31490  parents ' attitude towards their children 's m...
# 31491  They pay closer attention to market opportunit...
# 31492                          laughter is best medicine
# 31493       the writer gets along well with his only son
# 31494  Tally never left him when times were hard for ...
# 31495                      driving the elderly to church
# 31496                         Little Tom makes a mistake
# 31497         materialism has run wild in modern society
# 31498                he often mixed herbs for his mother
#
#                                               distractor
# 31479  'because he knew Farmer Joe was not hurt in th...
# 31480  'come from the university of Michigan - Flint'...
# 31481  "Sumsung 's SPH - V5400 and Nokia 's 6620", "S...
# 31482  'Duke of Zhou Interprets Dreams is a book abou...
# 31483  'one can be just as successful without having ...
# 31484  'Ritual uses music whereas drama does not .', ...
# 31485  'Having more floor space ', ' creating less po...
# 31486  'familiar dogs', 'a human the dog had never me...
# 31487  'How to read quickly .', 'Reading slowly is be...
# 31488  "an earthquake 's strength", 'widespread panic...
# 31489        'Because the underground water is rising .'
# 31490  "parents ' excuses for their children 's behav...
# 31491  'They stress on workers more than shareholders...
# 31492  'laughter and physical exercises have similar ...
# 31493  "the writer now seldom receives presents on Fa...
# 31494  'Tally brought the doctor to him after the acc...
# 31495  'helping put in local libraries', 'working as ...
# 31496  'Little Tom is a bad boy .', 'Little Tom often...
# 31497  'they are in fear of another Great Depression'...
# 31498  'he liked go play with herbs .', 'he studied a...

# %% [markdown]
# - We can observe that a lot of question seems to be taken from a passage but the passage is not being provided.

# %%
test.head(20)
# Out:
#                                              question  \
# 0                 What 'S the main idea of the text ?
# 1   In the summer high season , Finland does nt se...
# 2   If you want to apply for Chinese Business Inte...
# 3   That afternoon , the boy 's clothes were dry b...
# 4     Which of the following statements is NOT true ?
# 5   The problem of " lock - in " can be dangerous ...
# 6                         The passage is mainly about
# 7                Which of the following in not true ?
# 8                    What should you do at mealtime ?
# 9   The part of " Only you can make a card like th...
# 10  Why does Ben Brauch love his job of Santa impe...
# 11                                 Who is a blogger ?
# 12  According to the passage , Charles Darwin 's w...
# 13   What did Fly do when he pulled a piece of meat ?
# 14               What can we learn from the passage ?
# 15  It can be inferred from the passage that adver...
# 16  The downfall of the Arthur Andersen accounting...
# 17                                   Which is wrong ?
# 18  What 's the students ' attitude to universitie...
# 19        What would be the best title for the text ?
#
#                                           answer_text
# 0   The lack of career -- based courses in US high...
# 1                             the sun is out at night
# 2                have to get confirmed at least twice
# 3             nobody made room for him in the water .
# 4   There are twelve countries in the World Wildli...
# 5   it may make it difficult for customers to reco...
# 6       how Billy made blueberry juice with his uncle
# 7            The snail 's teeth ca n't be worn out ..
# 8           Eat the food your host family gives you .
# 9                   how to make a meaningful DIY card
# 10          Because he enjoys playing with children .
# 11      A person who posts text or photos in a blog .
# 12                           the voyage of the Beagle
# 13                   He pulled a plate to the floor .
# 14  Learn to forgive others and remember to be tha...
# 15                  give true information about goods
# 16                         its dishonesty in business
# 17                        Li Yun can sing very well .
# 18     Most of them are willing to go to university .
# 19                    A supper runner -- Patti Wilson

# %%
for row in range(100,200,1):
    print("Question-> ",train.iloc[row,0])
    print("Correct answer-> ",train.iloc[row,1])
    print("Distractors-> ",train.iloc[row,2])
    print("="*100)
# Out:
# Question->  Playing computer games
# Correct answer->  makes us more clever
# Distractors->  'makes our studies worse'
# ====================================================================================================
# Question->  By visiting the website you can learn more information about
# Correct answer->  Blue Ridge Folklike Festival
# Distractors->  'Boones Mill Apple Festival', 'Mountain Magic Fall Festival', 'Vinton Fall Festival'
# ====================================================================================================
# Question->  Women tend to go up the floor until they reach the top floor because
# Correct answer->  they think even better husbands may be upstairs
# Distractors->  'they think the husbands downstairs are not suitable', 'they are sure that the best husbands are on the top floor'
# ====================================================================================================
# Question->  When the moon shines , it is during the
# Correct answer->  night
# Distractors->  'day'
# ====================================================================================================
# Question->  The writer 's new level of sleep deprivation began since he
# Correct answer->  began to teach in a school
# Distractors->  'went 36 hours with no sleep'
# ====================================================================================================
# Question->  What did the Economic Mobility Project find in its research ?
# Correct answer->  The rags to riches story is more fiction than reality .
# Distractors->  'Children from low - income families are unable to bootstrap their way to the top .', 'Hollywood actors and actresses are upwardly mobile from rags to riches .', 'The rags to riches story is only true for a small minority of whites .'
# ====================================================================================================
# Question->  Why did Mr. Baker want to see the $ 2.00 model first ?
# Correct answer->  Because he wanted to pay less money for a hearing aid .
# Distractors->  'Because he thought all the hearing aids were the same .', 'Because he wanted to try a good earing aid first .'
# ====================================================================================================
# Question->  The following part might probably
# Correct answer->  describe how strangers went out of their way to help him
# Distractors->  'explain why people refused to help strangers'
# ====================================================================================================
# Question->  Why did O'Brien develop his own mnemonics ?
# Correct answer->  To win money while playing cards .
# Distractors->  'To become a world memory champion', 'To prove he had a good memory .', 'To defeat David Thomas .'
# ====================================================================================================
# Question->  Which of the following sentences is not right ?
# Correct answer->  You can only throw it with both hands
# Distractors->  "You must put the ball into the other side 's basket to score .", 'You can throw the ball into the basket from any part of the court .'
# ====================================================================================================
# Question->  The Universal Postal Union was formed
# Correct answer->  to help move mail quickly around the world
# Distractors->  'to help men meet in Switzerland', 'to look for the lost letters along the way'
# ====================================================================================================
# Question->  Who helped to create the American version of Pizza ?
# Correct answer->  Raffaele Esposito and Margherita .
# Distractors->  'Maria Carolina and Ernest Hamwi .', 'Ernest Hamwi and Forrest Mars ', ' Sr .'
# ====================================================================================================
# Question->  All through his life , Van Gogh
# Correct answer->  was not recognized by people
# Distractors->  'worked hard on art studies', 'expressed himself in paintings'
# ====================================================================================================
# Question->  What is the similarity between Doreen Sykora and Hitoshi Sakamoto ?
# Correct answer->  They both had experiences of test anxiety .
# Distractors->  'They are students from the same university .'
# ====================================================================================================
# Question->  We can infer ( ; ) from the passage that
# Correct answer->  the writer missed her father very much after his death
# Distractors->  "there were always a lot of people in the writer 's house", 'the writer was afraid of her father'
# ====================================================================================================
# Question->  From this passage we can see that
# Correct answer->  Ann can have more 1essons
# Distractors->  "Ann does n't 1ike playing the violin", "Ann does n't want to have more 1essons", "Ann 's father does n't have a friend"
# ====================================================================================================
# Question->  If we want to access more foreign countries and regions with better voice quality , we'd better choose_IP card .
# Correct answer->  China Mobile 's
# Distractors->  "China Unicom 's", "China Netcom 's", "China Telecom 's"
# ====================================================================================================
# Question->  Which of the following albums has a song adopted in a movie ?
# Correct answer->  " Bailamos " .
# Distractors->  '" Enrique Iglesias " .'
# ====================================================================================================
# Question->  Which of the following would be author agree with ?
# Correct answer->  Economic conditions are a major cause of crime
# Distractors->  'Most prisoners do not deserve to be in prison', 'Prison populations are likely to increase in the future'
# ====================================================================================================
# Question->  What is the impact from Apophis if it hits the earth ?
# Correct answer->  It might be the worst damage caused by asteroids in recorded history .
# Distractors->  'Thousands of square kilometers would see the effects of the dust released into the atmosphere .', 'The whole planet would be directly affected by the explosion .'
# ====================================================================================================
# Question->  What can be inferred according to the passage ?
# Correct answer->  The dispute between China and Japan has put the U.S. in a dilemma .
# Distractors->  'The claim from both sides has become more insistent .', 'Japan has navy and ability to power the Diaoyu Islands .', 'China is developing so quickly that it will declare a war on Japan .'
# ====================================================================================================
# Question->  What do we know about the phrase " your two cents " ?
# Correct answer->  It is usually used at the end of a statement .
# Distractors->  'It comes from " a penny for your thoughts " .', 'It is more familiar to people than " a penny for your thoughts " .'
# ====================================================================================================
# Question->  The main idea of the passage is that
# Correct answer->  progress does n't always bring about an improvement
# Distractors->  'modern medicine has made our lives better in some ways', 'the growth in population is mainly the result of medical progress', '" progress " is too difficult a word to understand'
# ====================================================================================================
# Question->  According to the news report , the aim of the summit in Londonis mainly to
# Correct answer->  seek solutions to the world economic crisis
# Distractors->  'build up new regulatory systems in each country', 'strengthen the economic relationship between countries'
# ====================================================================================================
# Question->  If a person calls"Rule 240",he wants to
# Correct answer->  get a ticket for the next flight
# Distractors->  'know if other flights are also delayed', 'ask about the reason for the plane delay'
# ====================================================================================================
# Question->  Why do people feel"squeezed"when their average income rises considerably ?
# Correct answer->  Their material demands go faster than their earnings .
# Distractors->  'There is more unemployment in modern society .'
# ====================================================================================================
# Question->  Which of the following is not true according to the passage ?
# Correct answer->  " Inspiration Mars ' would be a voyage of around 800 million miles around the Mars in 501 days , "
# Distractors->  'It will take private donors about $ 300 million for the mission according to " Inspiration Mars \' .', 'Tito plans to launch two astronauts to the Mars in December 2017 .', 'The Space Launch System is supposed to be ready for its first test flight in 2017 .'
# ====================================================================================================
# Question->  What can be learnt from the passage ?
# Correct answer->  Parents ' hope for their children 's career did not change too much .
# Distractors->  'Parents pay much attention to the income of their children .', "Less than half of the parents who were surveyed did n't follow their dreams .", "Most parents did n't have the necessary conditions to realize their dreams ."
# ====================================================================================================
# Question->  In their teacher 's eyes , why did they have so much stress ?
# Correct answer->  Because they cared too much about things that were not important .
# Distractors->  'Because they knew about life itself and enjoyed it .', 'Because they drank too much coffee .'
# ====================================================================================================
# Question->  At 9:30 pm , the writer begins to
# Correct answer->  listen to the play
# Distractors->  'send short messages to his friends'
# ====================================================================================================
# Question->  Who first had the idea of making a book from the story " Alice Adventures Under Ground " ?
# Correct answer->  George
# Distractors->  'Charles'
# ====================================================================================================
# Question->  Mr Wang paid for a new school . Some people did n't like the design of the school but they did n't argue with Mr Wang because
# Correct answer->  he who pays the piper calls the tune
# Distractors->  'once bitten ', ' twice shy', 'a bird in the hand is worth two in the bush'
# ====================================================================================================
# Question->  Which brain is the most developed ?
# Correct answer->  The human brain .
# Distractors->  'The largest brain .', 'The smaller brain .', 'Not too big brain .'
# ====================================================================================================
# Question->  If you want to get prize ,
# Correct answer->  please buy a packet of splash .
# Distractors->  'you should buy 500', '000 packets of splash .'
# ====================================================================================================
# Question->  In most US universities ,
# Correct answer->  some excellent students can graduate ahead of time
# Distractors->  'college students are offered the co - op program', "electives ' credits make up one quarter of the required credits", 'all students are required to finish four - year education before graduation'
# ====================================================================================================
# Question->  What method did Andrew Howell and his colleagues use in the study ?
# Correct answer->  Collecting information .
# Distractors->  'Observing people .', 'Interviewing people .'
# ====================================================================================================
# Question->  Which of the following is NOT true ?
# Correct answer->  Universities both at home and abroad have sponsored    the plan .
# Distractors->  'If the project is completed ', " the world 's longest tunnel will appear .", 'You can reach Taiwan from the mainland directly at present .', 'The starting point of the proposed tunnel is in Fujian .'
# ====================================================================================================
# Question->  Which of the following is right ?
# Correct answer->  Children usually eat more while watching TV .
# Distractors->  'Children usually eat fewer while watching TV .', 'Children eat the same amount of meals while watching TV .', 'Children usually eat nothing while watching TV .'
# ====================================================================================================
# Question->  According to the text , how is " my " English ?
# Correct answer->  I can master it but I ca n't use it correctly .
# Distractors->  'I am good at English .', 'I can speak English like natives .', 'I continued to study English at university .'
# ====================================================================================================
# Question->  What could be the best title of the passage ?
# Correct answer->  Always Follow the Principles in Life
# Distractors->  'A Smart Girl Has All Solutions', 'Be Careful about Beautiful Girls'
# ====================================================================================================
# Question->  The boy visited the wise man for
# Correct answer->  getting the secret of happiness
# Distractors->  'helping the wise man carry the oil', 'going sightseeing in the palace'
# ====================================================================================================
# Question->  What 's the purpose of Miss International beauty contest ?
# Correct answer->  promote international friendship
# Distractors->  'bath in the hot spring'
# ====================================================================================================
# Question->  What is the best title for the text ?
# Correct answer->  A Picture of a Smiling Horse
# Distractors->  'A Wonderful Picture'
# ====================================================================================================
# Question->  Gillian Swan developed Square Eyes
# Correct answer->  to deal with childhood obesity .
# Distractors->  'to gain enough TV time', 'to finish university design project .'
# ====================================================================================================
# Question->  Which of the following is WRONG ?
# Correct answer->  Li Hong has much pocket money .
# Distractors->  'Li Hong is very hard - working .', 'Li Hong wants to do something for her hometown .', 'Li Hong has been in Chongqing for 2 years .'
# ====================================================================================================
# Question->  In this passage , the writer suggests that
# Correct answer->  there should be legal controls over tourism in the Antarctic
# Distractors->  'people had better not make a tour of the Antarctic', 'ships to the Antarctic should be built strong enough', "the Antarctic 's environment is fragile"
# ====================================================================================================
# Question->  Which of the following is NOT true except the fact that
# Correct answer->  Miley 's 54-date North American concert tour was very successful .
# Distractors->  'Miley began to act at the age of 12 .', "Miley 's show ", ' Hannah Montana was popular with not kids but adults .', 'Miley is a regular and grounded girl .'
# ====================================================================================================
# Question->  According tothe laws in some countries , computer companies must
# Correct answer->  collect and recycle most of their products
# Distractors->  'repair and upgrade old computers', 'make more cheaper computers'
# ====================================================================================================
# Question->  The text is mainly about
# Correct answer->  how human activity affects our water supply
# Distractors->  'Why paving roads reduces our water', 'how much we depend on water to live'
# ====================================================================================================
# Question->  From this passage , we can know that
# Correct answer->  parents should try their best to keep away from spanking their children
# Distractors->  'good children always do the right thing', 'parents have to spank the children when they do something wrong', 'children can have more than one choice not to be spanked'
# ====================================================================================================
# Question->  Linda Waite 's studies support the idea that
# Correct answer->  Marriage can help make up for ill health
# Distractors->  'older men should quit smoking to stay healthy', 'Unmarried people are likely to suffer in later life'
# ====================================================================================================
# Question->  David Trezequet lost the game to Italy in
# Correct answer->  the 2006 World Cup in Germany
# Distractors->  'the European Cup', 'the French World Cup in 1998'
# ====================================================================================================
# Question->  The passage is mainly about
# Correct answer->  the changes of fashions
# Distractors->  'the money in fashion'
# ====================================================================================================
# Question->  Mr. Davis left the author with a very deep impression mainly because he
# Correct answer->  was a role model to teach hearts and change minds
# Distractors->  'spent much time helping the author with his homework'
# ====================================================================================================
# Question->  What does the author think of franchising ?
# Correct answer->  It will control the global economy .
# Distractors->  'It will bring higher business risk .'
# ====================================================================================================
# Question->  the writer develop the article mainly by
# Correct answer->  giving examples
# Distractors->  'following the time order', 'presenting the reasons of failure'
# ====================================================================================================
# Question->  A " property " in Australia is a
# Correct answer->  farm
# Distractors->  'school'
# ====================================================================================================
# Question->  What did the author do when traveling to Myrtle Beach ?
# Correct answer->  Have fun with his brother .
# Distractors->  'Play video games .'
# ====================================================================================================
# Question->  What should students pay attention to when using the library ?
# Correct answer->  Keeping their mobile phones silent all the time .
# Distractors->  'Using mobile phones only in the hallways or stairs .'
# ====================================================================================================
# Question->  The study Marc Turner did is different from those of many other   scientists in that
# Correct answer->  he grew   artificial blood using human stem cells
# Distractors->  'he was able   to discover the special function of type O- blood', 'he produced   the first artificial blood in the world', 'he used   special ingredients to produce artificial blood cells'
# ====================================================================================================
# Question->  According to the passage , the competition
# Correct answer->  aims to help poor children throughout the world
# Distractors->  'is a global painting Olympic for students worldwide', 'is a platform to find out children who have a gift for painting', 'is held once every four years like the Olympic Games'
# ====================================================================================================
# Question->  How will we feel if we let the clerk know the mistake ?
# Correct answer->  We 'll have a sense of honor .
# Distractors->  "We 'll feel sorry for the clerk ."
# ====================================================================================================
# Question->  What kind of people live a difficult life ?
# Correct answer->  Those who lead a dog 's life .
# Distractors->  'Those who have the dog days .', 'Those whose bark is worse than his bite .'
# ====================================================================================================
# Question->  Doyle was rather surprised because
# Correct answer->  the driver could call him by his name
# Distractors->  'the driver had seen him before'
# ====================================================================================================
# Question->  Which of the following statements about the Dubai Tower is TRUE according the passage ?
# Correct answer->  The Dubai Tower has apartments and a shopping mall .
# Distractors->  'The Dubai Tower is 508 meters tall and has more than 141 storeys .', 'The final height of the Dubai Tower is over 700 meters tall .', 'Samsung Corporation has completed building the Dubai Tower .'
# ====================================================================================================
# Question->  Which of the following moved the author ?
# Correct answer->  The homeless man bought food for the dog with all of his money
# Distractors->  "Most people walking by the dog did n't notice her", 'The homeless man wore worn clothes on the cold day', 'The homeless man had not any money to buy any food for himself'
# ====================================================================================================
# Question->  When she was over fifty , the late 19th century mother
# Correct answer->  was unlikely to find a job even if she is now likely
# Distractors->  'would expect to work until she died', 'was usually expected to take up paid employment'
# ====================================================================================================
# Question->  According to the passage , we can learn that
# Correct answer->  the old couple got divorced at last
# Distractors->  "the wife 's favorite food was the drumsticks", 'the husband knew his wife had heart problems', 'the wife bought an insurance policy for her husband'
# ====================================================================================================
# Question->  .We can conclude according to the passage that
# Correct answer->  the writer is worried about inflation
# Distractors->  'the writer encourages people to spend money', 'the writer has become richer because of inflation'
# ====================================================================================================
# Question->  By writing the passage , the author tries to show
# Correct answer->  we should try to rely on ourselves for everything
# Distractors->  'we can do nothing without money', "it 's hard for parents to bring up their children"
# ====================================================================================================
# Question->  When the writer did n't like the food his grandma cooked when he was growing up ,
# Correct answer->  he had to eat it or go without
# Distractors->  'his grandma would buy him fast food', 'he would sit there waiting for his favourite pizza pie'
# ====================================================================================================
# Question->  After hundreds of people sent money to help him ,
# Correct answer->  Huang Ge decided to thank everyone who had helped him
# Distractors->  'Huang Ge decided to ask for more', "Huang Ge 's story went on TV", 'Huang Ge had a happy life with his father at home'
# ====================================================================================================
# Question->  Which of the following would be the best title of the passage ?
# Correct answer->  How to make homework less work
# Distractors->  'Why students should do homework', 'It is high time teachers gave less homework'
# ====================================================================================================
# Question->  Which of the following serves as the best title for the story ?
# Correct answer->  A Teacher 's Touch
# Distractors->  "Ms. Hunter 's Surprise", "Ms. Hunter 's Challenge"
# ====================================================================================================
# Question->  Which of the following sentences is TRUE ?
# Correct answer->  The third pedestrian was kind - hearted but the driver would n't think so .
# Distractors->  'The driver slept well in his car .', 'The driver had a good rest in his car .', 'The driver would be happy when the third pedestrian told him the time .'
# ====================================================================================================
# Question->  According to Prof . Seashore ,
# Correct answer->  recognition words can become active ones
# Distractors->  'one has at least 80', '000 recognition words', "one 's recognition vocabulary includes active words and non -- active ones", "one 's active words grow with his recognition ones"
# ====================================================================================================
# Question->  Where will you sit if you want to fly in the balloon ?
# Correct answer->  Inside the basket
# Distractors->  'On top of the balloon', 'Inside the balloon'
# ====================================================================================================
# Question->  Which of the following sentences is NOT true ?
# Correct answer->  In the old days , people often ate dumplings because they were poor .
# Distractors->  'Most of the Chinese like dumplings very much .', 'It is said that if one eats the dumpling with the coin ', ' he will be lucky in the year .'
# ====================================================================================================
# Question->  Which of the following is NOT true ?
# Correct answer->  If people hold the cup for a longer time , he will pay less for it .
# Distractors->  'Many businessmen use this"touch " way to sell their things .', 'By touching the cup and holding it in their hands ', ' many people begin to feel the cup is theirs .', 'Car sellers send the buyers out on test drives and pet shop owners encourage people to play with the dogs in the window in order to sell them .'
# ====================================================================================================
# Question->  What is the passage mainly about ?
# Correct answer->  Harmony in family .
# Distractors->  'Negotiation in family .', 'Education in family .', 'Teenage trouble in family .'
# ====================================================================================================
# Question->  What is the passage mainly about ?
# Correct answer->  Express your gratitude to your loved ones in words .
# Distractors->  'In this life ', ' what did you miss .'
# ====================================================================================================
# Question->  The best title for this text would be
# Correct answer->  Pets Join the Workforce
# Distractors->  'Pets Help Attract Customers'
# ====================================================================================================
# Question->  How can people know that there is a plante round Barnard 's Star ?
# Correct answer->  Sometimes they see that the planet pulls the star to one side and makes it move slower
#  .
# Distractors->  'The planet is shining .', 'The planet is next to our earth .', 'The planet is a red one .'
# ====================================================================================================
# Question->  Why did the author 's   mom always say " Poor Tiffany " ?
# Correct answer->  She thought that Tiffany was spoiled by her mother .
# Distractors->  'She felt sorry for Tiffany because Tiffany was poor .', 'She wanted to tell a lie to comfort the author .', 'She told the author this and wanted her to help Tiffany .'
# ====================================================================================================
# Question->  Bedtime Math is an iPad app that
# Correct answer->  encourages children together with their parents to solve math story problems
# Distractors->  'requires parents and children to answer reading comprehension questions', "assesses children 's math achievement and parents ' nervousness with math", 'teaches children how to count ', ' recognize shapes and solve practical problems'
# ====================================================================================================
# Question->  What did Wendy and Peter teach Stoopy ?
# Correct answer->  To help pick up litter .
# Distractors->  'To empty litter cans .'
# ====================================================================================================
# Question->  When should you apply for a visa ?
# Correct answer->  The moment you have been accepted to a school in the US .
# Distractors->  'After the immigration officer permit you to enter the US .'
# ====================================================================================================
# Question->  Which of the following ways to stop smoking is NOT mentioned in the passage ?
# Correct answer->  Offering money to help people stop smoking .
# Distractors->  'Setting smoke - free areas .', 'Fighting with the tobacco companies .', 'Warning people about the danger of smoking by advertisements .'
# ====================================================================================================
# Question->  What is the reason that people ca n't sit under the tree like Newton ?
# Correct answer->  A willow barrier has been put around the tree .
# Distractors->  'There is something wrong with the apple tree .'
# ====================================================================================================
# Question->  The new " wellness"policy is declared in order to
# Correct answer->  reduce child overweight caused by bake food
# Distractors->  'help schools out of budget difficulties', 'help students save money spent on food', 'reduce the price of bake food sold in schools'
# ====================================================================================================
# Question->  The conductor punched the ticket of the Scots because
# Correct answer->  he thought there was only one person inside
# Distractors->  'he wanted to show pity on the five poor Scots'
# ====================================================================================================
# Question->  According to a Chinese newspaper , the best way to deal with the dispute is
# Correct answer->  declaring war on Japan without a moment 's delay
# Distractors->  'moving the islands to the mainland of China'
# ====================================================================================================
# Question->  According to the passage , such animals as deer , wolves and bears clean themselves by
# Correct answer->  replacing their skin and fur naturally
# Distractors->  'living with parasites', 'having a bath in a river or lake'
# ====================================================================================================
# Question->  To judge the length of the hair of her clients , Clements mainly depends on
# Correct answer->  her sense of touch
# Distractors->  "Kathy Braga 's guidance \n :"
# ====================================================================================================
# Question->  Those who feed pets on raw should do some necessary cleaning when
# Correct answer->  preparing raw meat for pets
# Distractors->  'touching the food containers', 'taking their pets out for a walk', 'preparing foods for human beings'
# ====================================================================================================
# Question->  The situation at the moment is that
# Correct answer->  a school 's fame is not important , as long as a child has a certificate .
# Distractors->  'many children who are suitable for a job have no proof of their suitability', 'children attending well - respected schools need not get certificates .', "a bright child does n't need a certificate a t all to get a good job ."
# ====================================================================================================
# Question->  What is the passage mainly about ?
# Correct answer->  Smell and its influence .
# Distractors->  'Sense ability and food tastes .', 'Olfactory genes and its system .'
# ====================================================================================================
# Question->  What is the best title of the passage ?
# Correct answer->  Love or money ?
# Distractors->  'Material wealth can guarantee happiness', 'Studies on sudden wealth'
# ====================================================================================================
# Question->  According to the text , which of the following has the longest history ?
# Correct answer->  San Francisco 's Chinatown .
# Distractors->  "London 's Chinatown .", "Bangkok 's Chinatown .", "Mauritius 's Chinatown ."
# ====================================================================================================
# Question->  The author stopped his work immediately because he
# Correct answer->  decided to drive home for fishing tools and take the old man fishing
# Distractors->  'needed to go and buy a big bobber and some worms he needed', 'had got to head home to deal with some urgent situations'
# ====================================================================================================

# %%
for row in range(100,200,1):
    print("Question-> ",test.iloc[row,0])
    print("Correct answer-> ",test.iloc[row,1])
    print("="*100)
# Out:
# Question->  Why did most of Chinese people believe to eat eggplant and gram to be healthy ?
# Correct answer->  Because the people think Zhang Wuben is a famous nutritionist and doctor .
# ====================================================================================================
# Question->  Which of the following is NOT TRUE according to the passage ?
# Correct answer->  Mrs. Anderson stole Charlie 's car at the request of her daughter .
# ====================================================================================================
# Question->  What is the topic of the talk in November ?
# Correct answer->  The work of the Thames Ironworks Heritage Trust .
# ====================================================================================================
# Question->  What do we know about space food from the text ?
# Correct answer->  Astronauts could eat apples in space in the past .
# ====================================================================================================
# Question->  The reading is mainly about
# Correct answer->  three friends at a school
# ====================================================================================================
# Question->  We can learn from the text that business English
# Correct answer->  pays more attention to the forms of expressions
# ====================================================================================================
# Question->  What can we infer from the passage ?
# Correct answer->  Friedman has got some supporters for his project .
# ====================================================================================================
# Question->  Which   is TRUE according to the article   ?
# Correct answer->  English meals are very simple .
# ====================================================================================================
# Question->  People with little education usually
# Correct answer->  have fewer chances to get a good job
# ====================================================================================================
# Question->  According to the passage , which of the following is true ?
# Correct answer->  The word " DINKS " appeared in an Asian country .
# ====================================================================================================
# Question->  According to the report above , three percent of the people do n't take all their holiday leave because
# Correct answer->  they are worried about their employer 's view on their taking holidays
# ====================================================================================================
# Question->  How did the farmers make their cows happy ?
# Correct answer->  They named each cow themselves .
# ====================================================================================================
# Question->  People from all parts of the world go to visit Venice because
# Correct answer->  it is beautiful and quite different from other cities
# ====================================================================================================
# Question->  According to the passage , which of the following is TRUE ?
# Correct answer->  The customers who can not pay can word as volunteers in stead .
# ====================================================================================================
# Question->  Everyone likes Tom because
# Correct answer->  he is friendly
# ====================================================================================================
# Question->  What does the author think of society toward motorists ?
# Correct answer->  Society forgives their rude driving .
# ====================================================================================================
# Question->  Why could n't the elephant get the fruit ?
# Correct answer->  Because the fruit was too high .
# ====================================================================================================
# Question->  According to the passage , we can know Where Are We Going , Dad ? is
# Correct answer->  originally from South Korea
# ====================================================================================================
# Question->  Which of the following statements is NOT true ?
# Correct answer->  People should take their naps secretly
# ====================================================================================================
# Question->  What is the passage mainly about ?
# Correct answer->  Benefits of advertising and its characteristics .
# ====================================================================================================
# Question->  To be generous , the writer thinks
# Correct answer->  you find it meaningful whatever you do
# ====================================================================================================
# Question->  The research mentioned in the passage is most probably about
# Correct answer->  the relevance between IQ and use of modern technology
# ====================================================================================================
# Question->  What can be inferred from the passage ?
# Correct answer->  John is optimistic about feeding the rising population .
# ====================================================================================================
# Question->  By " Your past is more complete than mine , " Mommy means
# Correct answer->  Shao - ming has got motherly care and a sense of roots
# ====================================================================================================
# Question->  This passage mainly tells us that
# Correct answer->  one 's memory can be trained
# ====================================================================================================
# Question->  What would be the best title for the text ?
# Correct answer->  Can birds really talk to us ?
# ====================================================================================================
# Question->  Two kinds of Sushi , Edo and Osaka , were probably named after
# Correct answer->  their birthplaces
# ====================================================================================================
# Question->  What was the outside bank guard 's reaction to the armed robbers ?
# Correct answer->  He was frightened to death by the robbers .
# ====================================================================================================
# Question->  In this passage , why did the young man start early in the day ?
# Correct answer->  He knew the tide was out on this particular morning .
# ====================================================================================================
# Question->  Sufjan Stevens composes songs about states to
# Correct answer->  let people know more about the US
# ====================================================================================================
# Question->  Which of the following statements is TRUE ?
# Correct answer->  Scientists are warning people noise can be harmful .
# ====================================================================================================
# Question->  What do we know about the author 's family ?
# Correct answer->  Her family lives not far from a church .
# ====================================================================================================
# Question->  The Future Stars is intended for
# Correct answer->  pre - school children
# ====================================================================================================
# Question->  What the cities mentioned above have in common is that they
# Correct answer->  all have many tourist attractions to enjoy
# ====================================================================================================
# Question->  Why did the author say she was in misery ?
# Correct answer->  Because she was doing poorly in her study .
# ====================================================================================================
# Question->  Where do the kids learn Chinese ?
# Correct answer->  In a weekend Chinese school in a church .
# ====================================================================================================
# Question->  The purpose of the passage is to
# Correct answer->  introduce some information about Peter Jackson
# ====================================================================================================
# Question->  Which is WRONG    ?
# Correct answer->  Sally and I are in the same class .
# ====================================================================================================
# Question->  The passage mainly tells us that
# Correct answer->  there are different ways to give directions in different parts of the world
# ====================================================================================================
# Question->  According to legend , if it is cloudy on February 2 ,
# Correct answer->  winter will end in a short time
# ====================================================================================================
# Question->  In the early times , the travelers
# Correct answer->  had lots of money
# ====================================================================================================
# Question->  What is the main idea of this passage ?
# Correct answer->  We should balance work with rest .
# ====================================================================================================
# Question->  Which of the following statements is TRUE concerning general intelligence ?
# Correct answer->  People doing well on one type of intelligence test do well on other tests .
# ====================================================================================================
# Question->  What message does the writer pass on at the end of the passage ?
# Correct answer->  She was aware that she had to kick the habit of being addicted to her iPhone .
# ====================================================================================================
# Question->  Why did the author decide to introduce a new shop to his mother ?
# Correct answer->  She is too old to go to the market as before .
# ====================================================================================================
# Question->  Which one of the following does n't contribute to Safina 's success ?
# Correct answer->  Her emotional explosion and volatile emotional state .
# ====================================================================================================
# Question->  According to the text , Rock Dimensions camps will
# Correct answer->  probably impress participants deeply
# ====================================================================================================
# Question->  What can we learn from the passage ?
# Correct answer->  The dummies books will continue to be popular .
# ====================================================================================================
# Question->  At the sight of the author , the rattlesnake
# Correct answer->  lay motionless but got ready to meet danger
# ====================================================================================================
# Question->  What is special about Caleb Street 's Inn ?
# Correct answer->  It has a golf course for guest
# ====================================================================================================
# Question->  The purpose of this writing is to
# Correct answer->  introduce a new kind of genetically - modified rice and its possible benefits
# ====================================================================================================
# Question->  It can be learned from the text that an assistant should offer you help
# Correct answer->  only when you have finished reading
# ====================================================================================================
# Question->  Which of the following is true ?
# Correct answer->  You are not late if you go to your classroom at 8 o'clock on Thursday .
# ====================================================================================================
# Question->  After listening to Mrs. Lemming 's story , Annabelle wished
# Correct answer->  she could be as great as Sophie
# ====================================================================================================
# Question->  What does the author say about most Facebook users ?
# Correct answer->  They do n't know their personal data enriches Facebook
# ====================================================================================================
# Question->  We do n't know that our eyes are of great importance until
# Correct answer->  we can not see clearly
# ====================================================================================================
# Question->  The address of the Shanghai Center Theater is
# Correct answer->  1376 Nanjing Road W
# ====================================================================================================
# Question->  According to Professor Cook , the rings of the trees
# Correct answer->  offer people information about the regional climate .
# ====================================================================================================
# Question->  Which one is probably not Dr. Sharon M. Draper 's job ?
# Correct answer->  doctor
# ====================================================================================================
# Question->  Which is the best title for the passage ?
# Correct answer->  A Trip to Know Margaret Mitchell .
# ====================================================================================================
# Question->  The laundry owners asked Ramesh to come later , because
# Correct answer->  they had to wait for the sun to come out to dry clothes
# ====================================================================================================
# Question->  According to the survey , which do people lose most frequently ?
# Correct answer->  Cell phones .
# ====================================================================================================
# Question->  Before the cheating , the author thought that
# Correct answer->  he was a decent child but not perfect
# ====================================================================================================
# Question->  What happened to them a few minute later ?
# Correct answer->  their car nearly hit another car
# ====================================================================================================
# Question->  Which of the following statements is TRUE to the facts about most organic produce sold in Britain ?
# Correct answer->  It is produced outside Britain .
# ====================================================================================================
# Question->  According to the passage , which of the following remains unknown so far ?
# Correct answer->  The working principle of suggestion therapy .
# ====================================================================================================
# Question->  A sound   scientific theory should be one that
# Correct answer->  works under one set of conditions at one time and also works under the same conditions at other times
# ====================================================================================================
# Question->  What 's the main idea of this passage ?
# Correct answer->  There are some ways to talk with our parents .
# ====================================================================================================
# Question->  According to the passage , Rodrigo Cruz
# Correct answer->  thinks people can use phones in emergencies while driving
# ====================================================================================================
# Question->  Why do about one - fourth of kids have poor handwriting in America ?
# Correct answer->  Each reason mentioned above is possible .
# ====================================================================================================
# Question->  What is Gemma Cope according to the passage ?
# Correct answer->  The manager of an tourist company .
# ====================================================================================================
# Question->  What is the main idea of the article ?
# Correct answer->  Why earthquakes seem to be more serious this year .
# ====================================================================================================
# Question->  Which of the following is true ?
# Correct answer->  The thief was caught two days later .
# ====================================================================================================
# Question->  Which of the following may be a suitable title for the story ?
# Correct answer->  Civilized Dog Raising
# ====================================================================================================
# Question->  The writer
# Correct answer->  is an American
# ====================================================================================================
# Question->  Which is TRUE about Brazil ?
# Correct answer->  Soccer and samba are two symbols of the country .
# ====================================================================================================
# Question->  What worried the Craigs ?
# Correct answer->  There was no cheetah mother to teach the cubs .
# ====================================================================================================
# Question->  Why was life able to develop on the earth but not on other planets ?
# Correct answer->  The water stayed on the earth but not on other planets .
# ====================================================================================================
# Question->  What is the passage mainly about ?
# Correct answer->  It instructs us how to water trees correctly
# ====================================================================================================
# Question->  What are guests supposed to do from 9:00 a. m. to 10:30 a. m. ?
# Correct answer->  To take a tour of the Thomas College campus .
# ====================================================================================================
# Question->  What did Mr. and Mrs. Gordon do when Sandra was carried out to sea by the wave ?
# Correct answer->  Perhaps they were reading magazines .
# ====================================================================================================
# Question->  Which of the following is TRUE according to the passage ?
# Correct answer->  The poor man had no money to buy food for his daughter .
# ====================================================================================================
# Question->  Kate thought Tom was wrong because
# Correct answer->  clocks in Los Angeles showed a different time from those in New York
# ====================================================================================================
# Question->  Why can imagination build children 's selfconfidence ?
# Correct answer->  It makes them feel as if they were much more powerful than they really are .
# ====================================================================================================
# Question->  Which of the following is WRONG ?
# Correct answer->  The author thinks tigers should stay in cages .
# ====================================================================================================
# Question->  When there is a traffic jam , we should
# Correct answer->  change the route if possible
# ====================================================================================================
# Question->  According to the article , phytomining
# Correct answer->  has different productivity depending on the type of energy crop
# ====================================================================================================
# Question->  From the passage we learn that uniforms in general
# Correct answer->  help the wearers keep their duties in mind
# ====================================================================================================
# Question->  According to the passage , alcohol has something to do with bad breath mainly because
# Correct answer->  it affects the normal flow of saliva
# ====================================================================================================
# Question->  What is the best title for the passage ?
# Correct answer->  An important suggestion for workers .
# ====================================================================================================
# Question->  What 's the best title for this text ?
# Correct answer->  Ways for future shopping
# ====================================================================================================
# Question->  Why did the mother and daughter go to the secondhand shop ?
# Correct answer->  Because they tried to keep themselves from the rain .
# ====================================================================================================
# Question->  At Beach Culture you can buy
# Correct answer->  Mambo and Stussy
# ====================================================================================================
# Question->  During the " failure week " the students could do the following things EXCEPT
# Correct answer->  trying to entertain themselves
# ====================================================================================================
# Question->  It can be inferred from the passage that
# Correct answer->  later life experience can lead to different EQ
# ====================================================================================================
# Question->  Which of the following is TRUE ?
# Correct answer->  Melvin 's teacher thinks it is a great thing to learn to help others .
# ====================================================================================================
# Question->  When it is winter in China ,
# Correct answer->  the North Pole is tilted away from the sun
# ====================================================================================================
# Question->  Which of the following is true ?
# Correct answer->  Alice ran after the white rabbit across the field out of curiosity .
# ====================================================================================================
# Question->  Which is TRUE ?
# Correct answer->  Everyone in Class Four likes Wendy .
# ====================================================================================================
# Question->  What would be the best title for the passage ?
# Correct answer->  Deb Lovci --2015 's Best Ski Guide
# ====================================================================================================

# %%
train['distractor'][1].split(', ')
# Out:
# ["'If some tragedies occur again '",
#  "' relevant departments of the State Council should take responsibility completely .'",
#  "'Currently '",
#  "' the central government has established sound management systems to guarantee school bus safety .'",
#  "'Central and local governments will share the costs on building more modern schools in rural areas .'"]

# %%
train['num_distractors'] = train['distractor'].map(lambda x: len(x.split(',')))

# %%
train.head()
# Out:
#                                             question  \
# 0                                Meals can be served
# 1           It can be inferred from the passage that
# 2     The author called Tommy 's parents in order to
# 3           It can be inferred from the passage that
# 4  How can we deal with snake wounds according to...
#
#                                          answer_text  \
# 0                             in rooms at 9:00 p. m.
# 1  The local government can deal with the problem...
# 2         help them realize their influence on Tommy
# 3       the writer is not very willing to use idioms
# 4                        Stay calm and do n't move .
#
#                                           distractor  num_distractors
# 0  'outside the room at 3:00 p. m.', 'in the dini...                3
# 1  'If some tragedies occur again ', ' relevant d...                5
# 2  'blame Tommy for his failing grades', 'blame T...                2
# 3  'idioms are the most important part in a langu...                3
# 4          'Cut the wound and suck the poison out .'                1

# %% [markdown]
# - Some questions have more than 3 distractor and some questions have only 1 distractor.

# %% [markdown]
# <h3> Different ways of producing sentence embeddings: </h3>
#
# 1. **Avg-W2V:** Words can be converted to vectors by producing their W2V embeddings. For sentences we can take average of the all the word embeddings to produce the sentence embedding. Since this is based of indivdual word embeddings this does not consider the context, POS of the words, Voice of the sentences.
# 2. **Avg-W2V (Glove):** Leverages a pretrained Glove model to produce sentence embeddings. This is said to also consider the context of the words.
# 3. **Sentence Transformers:** Sentence Embeddings using BERT. Tunes a model on Natural Language Inference (NLI) data. Given two sentences, the model should classify if these two sentence entail, contradict, or are neutral to each other. For this, the two sentences are passed to a transformer model to generate fixed-sized sentence embeddings. These sentence embeddings are then passed to a softmax classifier to derive the final label (entail, contradict, neutral). This generates sentence embeddings that are useful also for other tasks like clustering or semantic textual similarity.

# %% [markdown]
# <h4> Constructing sentence embeddings: </h4>
#
# Choosing 'bert-base-nli-mean-tokens' and 'bert-base-nli-stsb-mean-tokens' pretrained sentence embeddings model for constructing sentence embedings/vectors.

# %%
from sentence_transformers import SentenceTransformer
import scipy.spatial

#Leveraging pretrained models, loading pre-trained models from the server:
#embedder = SentenceTransformer('bert-base-nli-mean-tokens') # STSbenchmark: 77.12
embedder = SentenceTransformer('bert-base-nli-stsb-mean-tokens')# STSbenchmark: 85.14

# %%
#
distractors = [train['distractor'][i].split(',') for i in range(train.shape[0])] #
candidate_distractors = [distractors[i][j] for i in range(len(distractors)) for j in range(len(distractors[i]))]

# %%
# %%time
# Corpus with the candidate_distractors from train
corpus = candidate_distractors
corpus_embeddings = embedder.encode(candidate_distractors) #Pytorch makes use of GPU acceleration.
# Out:
# Wall time: 8min 17s

# %%
#Saving the embeddings for future use.
np.save("corpus_embeddings.npy",corpus_embeddings)
corpus_embeddings = np.load("corpus_embeddings.npy")
print(np.shape(corpus_embeddings))
# Out:
# (70796, 768)

# %%
# Considering combination of Questions and answers as Query sentences: 
q_a_combined = test['question'] + " " + test['answer_text']

# %%
# %%time
query_embeddings = embedder.encode(q_a_combined)
# Out:
# Wall time: 1min 51s

# %%
#Saving the embeddings for future use.
np.save("query_embeddings.npy",query_embeddings)
query_embeddings = np.load("query_embeddings.npy")
print(np.shape(query_embeddings))
# Out:
# (13500, 768)

# %%
# Finding the closest 3 distractors from the corpus of distractors for each query sentence based on cosine similarity
closest_n = 3 
#Creating DataFrame for accomodating all the 3 distractors for each question in Test.
dis3 = pd.DataFrame(data=[[0 for i in range(closest_n)] for j in range(test.shape[0])], \
                    columns=['distractor_'+str(i) for i in range(closest_n)])
i=0
for query, query_embedding in tqdm(zip(q_a_combined[:], query_embeddings[:])):
    #Calculating cosine distance of every distractor from a query.
    distances = scipy.spatial.distance.cdist([query_embedding], corpus_embeddings, "cosine")[0]

    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])
    

    #print("\n\n======================\n\n")
    #print("Query:", query)
    #print("\nTop 5 most similar sentences in corpus:")
    j=0
    for idx, distance in results[0:closest_n]:
        #Assigning potential distract from Train to question-answer pairs in Test.
        #print(distance)
        #print(corpus[idx].strip(), "(Score: %.4f)" % (1-distance))
        dis3.iloc[i,j] = corpus[idx].strip()
        j+=1
    i+=1
# Out:
# 13500it [1:32:03,  2.49it/s]

# %%
dis3.head()
# Out:
#                                         distractor_0  \
# 0   "thought the author was n't fit to be a teacher"
# 1  'a late nap may lead to sleep problems during ...
# 2                       'Starting Business in China'
# 3  'He thought it was such a big swimming pool th...
# 4  '12 zoos are involved in the program in the US .'
#
#                                         distractor_1  \
# 0  'Students are not interested in their curricul...
# 1  'Sleeping late on weekends can make up for los...
# 2  'Beijing No.4 Middle School has been encouragi...
# 3             'there was no water to wash his hands'
# 4                                     '000 to A$ 12'
#
#                                         distractor_2
# 0  'middle school graduates should not choose the...
# 1  'the ways to get a better sleep on a full moon...
# 2  'learning how to make Chinese dishes is very p...
# 3                               'Nobody needs water'
# 4  ' so it is hard to tell whether a child is a b...

# %%
#Combining all 3 distractors
dis3['distractors'] = dis3.iloc[:,0]+","+dis3.iloc[:,1]+","+dis3.iloc[:,2]

dis3.to_csv('dis3_v2.csv')

# %%
test['distractor'] = dis3['distractors']

test[['question', 'answer_text','distractor']].to_csv('results_2.csv',index=False)

# %%
test[['question', 'answer_text','distractor']].head()
# Out:
#                                             question  \
# 0                What 'S the main idea of the text ?
# 1  In the summer high season , Finland does nt se...
# 2  If you want to apply for Chinese Business Inte...
# 3  That afternoon , the boy 's clothes were dry b...
# 4    Which of the following statements is NOT true ?
#
#                                          answer_text  \
# 0  The lack of career -- based courses in US high...
# 1                            the sun is out at night
# 2               have to get confirmed at least twice
# 3            nobody made room for him in the water .
# 4  There are twelve countries in the World Wildli...
#
#                                           distractor
# 0  "thought the author was n't fit to be a teache...
# 1  'a late nap may lead to sleep problems during ...
# 2  'Starting Business in China','Beijing No.4 Mid...
# 3  'He thought it was such a big swimming pool th...
# 4  '12 zoos are involved in the program in the US...
